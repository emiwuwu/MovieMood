# %% [markdown]
# # Sentitment Analysis

# %% [markdown]
# ## Import Dependencies

# %%
import re
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from bs4 import BeautifulSoup
import warnings
warnings.simplefilter("ignore")

# Import NLTK for natural language processing
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# Import TensorFlow and Keras for deep learning
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Flatten,Dense,Conv1D,GlobalAveragePooling1D,MaxPooling1D
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers.legacy import Adam
from keras.callbacks import EarlyStopping

# Import scikit-learn functions for data splitting and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## Parameters

# %%
TRAIN_SIZE= 0.8

MAX_NUM_WORDS = 100000
MAX_SEQUENCE_LEN = 250
EMBEDDING_DIM = 100

EPOCHS = 10
BATCH_SIZE = 32
LR= 0.005

# EXPORT
MODEL_PATH = 'models/sentiment_analysis_model.h5'
TOKENIZER_MODEL = "models/tokenizer.pickle"
ENCODER_MODEL = "models/encoder.pickle"

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df = pd.read_csv('./Resources/IMDB Dataset.csv', engine='python')

df.columns = ['text', 'target']

# %% [markdown]
# **First few rows of DataFrame**

# %%
df.head()
# Out:
#                                                 text    target
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# **Last few rows of DataFrame**

# %%
df.tail()
# Out:
#                                                     text    target
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %% [markdown]
# **Dataset Size**

# %%
print("Dataset Size:", len(df))
# Out:
# Dataset Size: 50000

# %% [markdown]
# **DataFrame Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    50000 non-null  object
#  1   target  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# **Target Label Assignment and Sentiment Distribution Analysis**
#
# In the next steps, we aimed for a balanced distribution with roughly equal examples for each class.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

df['target'].value_counts().plot.pie(
    explode=[0, 0.1],
    autopct='%1.1f%%',
    ax=ax1,
    shadow=True,
    startangle=120,
    colors=["#4682A9", "#7BAFD2"]
)
ax1.set_title('Sentiment Labels Distribution')
ax1.set_ylabel('')

df['target'].value_counts().plot(kind="bar", ax=ax2, color=["#4682A9", "#7BAFD2"])
ax2.set_title('Sentiment Labels Distribution')
plt.show()

# %% [markdown]
# - The data is uniformly distributed, eliminating the need for resampling.

# %% [markdown]
# ## Text Data Preprocessing

# %% [markdown]
# 1. **Lowercasing**: Convert all text to lowercase to ensure uniformity and prevent case-based duplication.
# 2. **Regex Cleaning**: Use regular expressions (regex) to clean the text. This step removes special characters, URLs, and mentions (e.g., "@username") from the text.
# 3. **Stopword Removal**: Eliminate common stopwords, such as "the," "and," and "is," from the text. This reduces noise in the data.
# 4. **HTML Tag Removal**: Parse HTML and retrieve clean, tag-free text.
#
# These preprocessing steps are commonly used to prepare text data for analysis or natural language processing tasks.

# %%
stop_words = set(stopwords.words("english"))
stemmer = SnowballStemmer("english")
regex_text = r"[^A-Za-z]+"

# %%
def preprocess_text(text, stem=False):
    
    text= BeautifulSoup(text).get_text()
    text = re.sub(regex_text, ' ', str(text).lower()).strip()
    
    tokens = []
    
    for word in text.split():
        if word not in stop_words:
            if stem:
                tokens.append(stemmer.stem(word))
            else:
                tokens.append(word)
                
    return " ".join(tokens)

# %%
# %%time
df['text']=df['text'].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 6.8 s, sys: 12.5 ms, total: 6.81 s
# Wall time: 6.56 s

# %% [markdown]
# **Positive Words**

# %%
plt.figure(figsize = (16,8))
positive_wordcloud = WordCloud (
                    background_color = 'white',
                    width = 1000,
                    height = 400,
                    colormap = 'cool',
                    max_words=500,
                    contour_width=1,
                    contour_color='steelblue').generate(' '.join(df[df['target'] == 'positive']['text']))

plt.imshow(positive_wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Negative Words**

# %%
plt.figure(figsize = (16,8))
negative_wordcloud = WordCloud (
                    background_color = 'white',
                    width = 1000,
                    height = 400,
                    colormap = 'viridis',
                    max_words=500,
                    contour_width=1,
                    contour_color='darkred').generate(' '.join(df[df['target'] == 'negative']['text']))

plt.imshow(negative_wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# - Surprisingly, the word clouds for both positive and negative sentiments yield the same result: "One", "film" and "movie."

# %% [markdown]
# ### Train and Test Split

# %%
train_data, test_data= train_test_split(df, test_size=1-TRAIN_SIZE, random_state=78)

# %% [markdown]
# ### Tokenization and Padding for Sequences

# %%
# %%time
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data.text)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
print("Total Words :", vocab_size)
# Out:
# Total Words : 92211
# CPU times: user 1.83 s, sys: 6.4 ms, total: 1.83 s
# Wall time: 1.5 s

# %%
# %%time
X_train = pad_sequences(tokenizer.texts_to_sequences(train_data['text']), maxlen=MAX_SEQUENCE_LEN)
X_test = pad_sequences(tokenizer.texts_to_sequences(test_data['text']), maxlen=MAX_SEQUENCE_LEN)

print("Train X Shape:", X_train.shape)
print("Test X Shape", X_test.shape)
# Out:
# Train X Shape: (40000, 250)
# Test X Shape (10000, 250)
# CPU times: user 1.2 s, sys: 16.9 ms, total: 1.22 s
# Wall time: 1.24 s

# %% [markdown]
# **Label Encoding**

# %%
labels= df['target'].unique().tolist()
labels
# Out:
# ['positive', 'negative']

# %%
encoder = LabelEncoder()
encoder.fit(train_data['target'].to_list())

y_train = encoder.transform(train_data['target'].to_list())
y_test = encoder.transform(test_data['target'].to_list())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (40000, 1)
# y_test shape: (10000, 1)

# %% [markdown]
# ### Word Embedding
#
# Utilizing pre-trained GloVe word vectors improves NLP model performance, minimizes data requirements, and harnesses semantic word representations effectively.

# %%
embeddings_index = {}

with open("Resources/glove.6B.100d.txt") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs 

print(f'Found {len(embeddings_index)} word vectors.')
# Out:
# Found 400000 word vectors.

# %%
embedding_matrix = np.zeros((vocab_size, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Build the Simple Model
#
# The basic model employs an embedding layer to transform textual tokens into fixed-length vectors. This layer takes the input text sequence and turns it into a sequence of vectors. Subsequently, it applies average pooling operations and concludes with a final fully-connected layer.

# %%
def model_builder():
    
    model = Sequential([
        Embedding(embedding_matrix.shape[0],
                            embedding_matrix.shape[1],
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LEN,  
                            trainable=False),
        GlobalAveragePooling1D(),
        Dense(16,activation='relu' ),
        Dense(1, activation='sigmoid')], name="simple_model")

    return model

# %%
model= model_builder()
model.summary()
# Out:
# Model: "simple_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 250, 100)          9221100
#
#  global_average_pooling1d (  (None, 100)               0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                1616
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 9222733 (35.18 MB)
# Trainable params: 1633 (6.38 KB)
# Non-trainable params: 9221100 (35.18 MB)
# _________________________________________________________________

# %% [markdown]
# **Compile the Model**

# %%
model.compile(optimizer=Adam(learning_rate=LR), 
              loss=BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# **Train the Model**

# %%
# %%time
history= model.fit(X_train, y_train, 
                   batch_size= BATCH_SIZE,
                   epochs= EPOCHS, 
                   validation_split= 0.1,
                   verbose=1)
# Out:
# Epoch 1/10
# 1125/1125 [==============================] - 1s 752us/step - loss: 0.5190 - accuracy: 0.7586 - val_loss: 0.4782 - val_accuracy: 0.7847
# Epoch 2/10
# 1125/1125 [==============================] - 1s 677us/step - loss: 0.4697 - accuracy: 0.7856 - val_loss: 0.4620 - val_accuracy: 0.7868
# Epoch 3/10
# 1125/1125 [==============================] - 1s 685us/step - loss: 0.4557 - accuracy: 0.7896 - val_loss: 0.4508 - val_accuracy: 0.7928
# Epoch 4/10
# 1125/1125 [==============================] - 1s 661us/step - loss: 0.4500 - accuracy: 0.7936 - val_loss: 0.4526 - val_accuracy: 0.7883
# Epoch 5/10
# 1125/1125 [==============================] - 1s 688us/step - loss: 0.4454 - accuracy: 0.7938 - val_loss: 0.4390 - val_accuracy: 0.7968
# Epoch 6/10
# 1125/1125 [==============================] - 1s 645us/step - loss: 0.4419 - accuracy: 0.7951 - val_loss: 0.4443 - val_accuracy: 0.7975
# Epoch 7/10
# 1125/1125 [==============================] - 1s 643us/step - loss: 0.4385 - accuracy: 0.7977 - val_loss: 0.4422 - val_accuracy: 0.7930
# Epoch 8/10
# 1125/1125 [==============================] - 1s 676us/step - loss: 0.4372 - accuracy: 0.7981 - val_loss: 0.4425 - val_accuracy: 0.7955
# Epoch 9/10
# 1125/1125 [==============================] - 1s 676us/step - loss: 0.4352 - accuracy: 0.7987 - val_loss: 0.4350 - val_accuracy: 0.7997
# Epoch 10/10
# 1125/1125 [==============================] - 1s 690us/step - loss: 0.4341 - accuracy: 0.8008 - val_loss: 0.4434 - val_accuracy: 0.7995
# CPU times: user 13.3 s, sys: 7.59 s, total: 20.8 s
# Wall time: 7.85 s

# %% [markdown]
# **Model Evaluation**

# %%
# %%time
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# 313/313 [==============================] - 0s 570us/step - loss: 0.4487 - accuracy: 0.7870
# Test loss: 0.4487
# Test accuracy: 78.70%
# CPU times: user 381 ms, sys: 184 ms, total: 565 ms
# Wall time: 244 ms

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt .ylim(0,1)
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt .ylim(0,1)
plt.legend()

plt.show()

# %% [markdown]
# - The basic model achieved an accuracy of 78.8% on the test data, yielding a loss of 0.4487. In cross-validation, the model demonstrated a slightly higher accuracy of 79.95% with a loss of 0.4434. Notably, no early stopping mechanism was implemented during training.
#
# - The model exhibits minimal overfitting as the accuracy and loss values between training and cross-validation closely align. This suggests that the model generalizes well to unseen data, resulting in a balanced performance across both training and validation sets.

# %% [markdown]
# ### Build the Complex Model
#
# CNN (convolutional neural network) is used for our advanced model. This model employs an embedding layer to convert textual tokens into fixed-length vectors, creating a sequence of vectors from the input text. These vectors then undergo several layers of convolution and max pooling operations before reaching a final fully-connected layer. To prevent overfitting, an implemented callback mechanism halts training early if the validation loss fails to improve for a certain number of consecutive times.

# %%
def opt_model_builder():
    
    model = Sequential([
        Embedding(embedding_matrix.shape[0],
                            embedding_matrix.shape[1],
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LEN,  
                            trainable=False),
        Conv1D(128, 5, activation='relu', padding="same"),
        MaxPooling1D(5, padding="same"),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')], name= "complex_model")

    return model

# %%
model= opt_model_builder()
model.summary()
# Out:
# Model: "complex_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 250, 100)          9221100
#
#  conv1d (Conv1D)             (None, 250, 128)          64128
#
#  max_pooling1d (MaxPooling1  (None, 50, 128)           0
#  D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense_2 (Dense)             (None, 128)               819328
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10104685 (38.55 MB)
# Trainable params: 883585 (3.37 MB)
# Non-trainable params: 9221100 (35.18 MB)
# _________________________________________________________________

# %% [markdown]
# **Compile the Model**

# %%
model.compile(optimizer=Adam(learning_rate=LR), 
              loss=BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# **Callbacks**

# %%
callbacks =[EarlyStopping(monitor='val_loss', patience=3)]

# %% [markdown]
# **Train the Model**

# %%
# %%time
history= model.fit(X_train, y_train, 
                   batch_size= BATCH_SIZE,
                   epochs= EPOCHS, 
                   validation_split= 0.1,
                   verbose=1,
                   callbacks= callbacks)
# Out:
# Epoch 1/10
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.4722 - accuracy: 0.7685 - val_loss: 0.3812 - val_accuracy: 0.8342
# Epoch 2/10
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.3570 - accuracy: 0.8452 - val_loss: 0.3842 - val_accuracy: 0.8317
# Epoch 3/10
# 1125/1125 [==============================] - 12s 11ms/step - loss: 0.3155 - accuracy: 0.8653 - val_loss: 0.4045 - val_accuracy: 0.8285
# Epoch 4/10
# 1125/1125 [==============================] - 12s 11ms/step - loss: 0.2666 - accuracy: 0.8890 - val_loss: 0.4505 - val_accuracy: 0.8225
# CPU times: user 3min 55s, sys: 38.6 s, total: 4min 33s
# Wall time: 47.2 s

# %% [markdown]
# **Model Evaluation**

# %%
# %%time
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4321 - accuracy: 0.8330
# Test loss: 0.4321
# Test accuracy: 83.30%
# CPU times: user 6.63 s, sys: 522 ms, total: 7.15 s
# Wall time: 1.17 s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt .ylim(0,1)
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt .ylim(0,1)
plt.legend()

plt.show()

# %% [markdown]
# - The complex model attained an accuracy of 83.3% on the test data with a corresponding loss of 0.4321. In cross-validation, the model exhibited a slightly lower accuracy of 82.25% and a loss of 0.4504. Early stopping was applied, concluding training after only 4 epochs due to a noticeable divergence between the training and validation loss, signaling effective early stopping.

# %% [markdown]
# **Predict**

# %%
def decode_sentiment(score):
    return "positive" if score > 0.5 else "negative"

# %%
def predict(text):
    # Tokenize text
    X_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=MAX_SEQUENCE_LEN)
    
    # Predict
    score = model.predict([X_test])[0]
    # Decode sentiment
    label = decode_sentiment(score)

    return {"label": label, "score": float(score)}

# %%
predict("The best movie I have ever watched")
# Out:
# 1/1 [==============================] - 0s 41ms/step
# {'label': 'positive', 'score': 0.905633807182312}

# %%
predict("I hate the movie")
# Out:
# 1/1 [==============================] - 0s 7ms/step
# {'label': 'negative', 'score': 0.2728841006755829}

# %% [markdown]
# **Confusion Matrix**

# %%
# %%time
scores = model.predict(X_test, verbose=1, batch_size=10000)
y_pred_1d = [decode_sentiment(score) for score in scores]
# Out:
# 1/1 [==============================] - 1s 1s/step
# CPU times: user 6.7 s, sys: 1.43 s, total: 8.14 s
# Wall time: 1.39 s

# %%
cm= confusion_matrix(test_data['target'],y_pred_1d)
cm = (cm.astype('float') / cm.sum(axis=1))*100
df_cm= pd.DataFrame(cm, index=['True Positive', 'True Negative'], columns=['Predict Positive', 'Predict Negative'])
df_cm
# Out:
#                Predict Positive  Predict Negative
# True Positive         82.751784         17.554479
# True Negative         15.860428         83.857950

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(list(test_data['target']), y_pred_1d))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.83      0.83      5044
#     positive       0.83      0.84      0.83      4956
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000

# %% [markdown]
# - The classification report indicates balanced performance for both positive and negative sentiments, with precision, recall, and F1-score values around 0.83. The overall accuracy of 83% suggests a well-performing model on the test data, achieving consistent results for both sentiment classes.

# %% [markdown]
# ### Save the Model

# %%
model.save(MODEL_PATH)
pickle.dump(tokenizer, open(TOKENIZER_MODEL, "wb"), protocol=pickle.HIGHEST_PROTOCOL)
pickle.dump(encoder, open(ENCODER_MODEL, "wb"), protocol=pickle.HIGHEST_PROTOCOL)
