# %% [markdown]
# # Sentitment Analysis

# %% [markdown]
# ## Import Dependencies

# %%
import re
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from bs4 import BeautifulSoup
import warnings
warnings.simplefilter("ignore")

# Import NLTK for natural language processing
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# Import TensorFlow and Keras for deep learning
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Flatten,Dense,Conv1D,GlobalAveragePooling1D,MaxPooling1D
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers.legacy import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

# Import scikit-learn functions for data splitting and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## Parameters

# %%
TRAIN_SIZE= 0.8

MAX_NUM_WORDS = 100000
MAX_SEQUENCE_LEN = 250
EMBEDDING_DIM = 100

EPOCHS = 10
BATCH_SIZE = 32
LR= 0.005

# EXPORT
MODEL_PATH = 'models/sentiment_analysis_model.h5'
TOKENIZER_MODEL = "models/tokenizer.pickle"
ENCODER_MODEL = "models/encoder.pickle"

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
df = pd.read_csv('./Resources/IMDB Dataset.csv', engine='python')

df.columns = ['text', 'target']

# %% [markdown]
# **First few rows of DataFrame**

# %%
df.head()
# Out:
#                                                 text    target
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# **Last few rows of DataFrame**

# %%
df.tail()
# Out:
#                                                     text    target
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %% [markdown]
# **Dataset Size**

# %%
print("Dataset Size:", len(df))
# Out:
# Dataset Size: 50000

# %% [markdown]
# **DataFrame Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    50000 non-null  object
#  1   target  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# **Target Label Assignment and Sentiment Distribution Analysis**
#
# In the next steps, we aimed for a balanced distribution with roughly equal examples for each class.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

df['target'].value_counts().plot.pie(
    explode=[0, 0.1],
    autopct='%1.1f%%',
    ax=ax1,
    shadow=True,
    startangle=120,
    colors=["#4682A9", "#7BAFD2"]
)
ax1.set_title('Sentiment Labels Distribution')
ax1.set_ylabel('')

df['target'].value_counts().plot(kind="bar", ax=ax2, color=["#4682A9", "#7BAFD2"])
ax2.set_title('Sentiment Labels Distribution')
plt.show()

# %% [markdown]
# - The data is uniformly distributed, eliminating the need for resampling.

# %% [markdown]
# ## Text Data Preprocessing

# %% [markdown]
# 1. **Lowercasing**: Convert all text to lowercase to ensure uniformity and prevent case-based duplication.
# 2. **Regex Cleaning**: Use regular expressions (regex) to clean the text. This step removes special characters, URLs, and mentions (e.g., "@username") from the text.
# 3. **Stopword Removal**: Eliminate common stopwords, such as "the," "and," and "is," from the text. This reduces noise in the data.
# 4. **HTML Tag Removal**: Parse HTML and retrieve clean, tag-free text.
#
# These preprocessing steps are commonly used to prepare text data for analysis or natural language processing tasks.

# %%
stop_words = set(stopwords.words("english"))
stemmer = SnowballStemmer("english")
regex_text = r"[^A-Za-z]+"

# %%
def preprocess_text(text, stem=False):
    
    text= BeautifulSoup(text).get_text()
    text = re.sub(regex_text, ' ', str(text).lower()).strip()
    
    tokens = []
    
    for word in text.split():
        if word not in stop_words:
            if stem:
                tokens.append(stemmer.stem(word))
            else:
                tokens.append(word)
                
    return " ".join(tokens)

# %%
# %%time
df['text']=df['text'].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 7.4 s, sys: 21.9 ms, total: 7.42 s
# Wall time: 7.18 s

# %% [markdown]
# **Positive Words**

# %%
plt.figure(figsize = (16,8))
positive_wordcloud = WordCloud (
                    background_color = 'white',
                    width = 1000,
                    height = 400,
                    colormap = 'cool',
                    max_words=500,
                    contour_width=1,
                    contour_color='steelblue').generate(' '.join(df[df['target'] == 'positive']['text']))

plt.imshow(positive_wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Negative Words**

# %%
plt.figure(figsize = (16,8))
negative_wordcloud = WordCloud (
                    background_color = 'white',
                    width = 1000,
                    height = 400,
                    colormap = 'viridis',
                    max_words=500,
                    contour_width=1,
                    contour_color='darkred').generate(' '.join(df[df['target'] == 'negative']['text']))

plt.imshow(negative_wordcloud, interpolation= 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# - Surprisingly, the word clouds for both positive and negative sentiments yield the same result: "One", "film" and "movie."
# -  These words could be commonly used in reviews that don't express extreme positive or negative opinions.

# %% [markdown]
# ### Train and Test Split

# %%
train_data, test_data= train_test_split(df, test_size=1-TRAIN_SIZE, random_state=78)

# %% [markdown]
# ### Tokenization and Padding for Sequences

# %%
# %%time
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data.text)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
print("Total Words :", vocab_size)
# Out:
# Total Words : 92211
# CPU times: user 1.89 s, sys: 5.58 ms, total: 1.9 s
# Wall time: 1.57 s

# %%
# %%time
X_train = pad_sequences(tokenizer.texts_to_sequences(train_data['text']), maxlen=MAX_SEQUENCE_LEN)
X_test = pad_sequences(tokenizer.texts_to_sequences(test_data['text']), maxlen=MAX_SEQUENCE_LEN)

print("Train X Shape:", X_train.shape)
print("Test X Shape", X_test.shape)
# Out:
# Train X Shape: (40000, 250)
# Test X Shape (10000, 250)
# CPU times: user 1.24 s, sys: 10.9 ms, total: 1.26 s
# Wall time: 1.26 s

# %% [markdown]
# **Label Encoding**

# %%
labels= df['target'].unique().tolist()
labels
# Out:
# ['positive', 'negative']

# %%
encoder = LabelEncoder()
encoder.fit(train_data['target'].to_list())

y_train = encoder.transform(train_data['target'].to_list())
y_test = encoder.transform(test_data['target'].to_list())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (40000, 1)
# y_test shape: (10000, 1)

# %% [markdown]
# ### Word Embedding
#
# Utilizing pre-trained GloVe word vectors improves NLP model performance, minimizes data requirements, and harnesses semantic word representations effectively.

# %%
embeddings_index = {}

with open("Resources/glove.6B.100d.txt") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs 

print(f'Found {len(embeddings_index)} word vectors.')
# Out:
# Found 400000 word vectors.

# %%
embedding_matrix = np.zeros((vocab_size, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Build the Simple Model
#
# The basic model employs an embedding layer to transform textual tokens into fixed-length vectors. This layer takes the input text sequence and turns it into a sequence of vectors. Subsequently, it applies **average pooling** operations and concludes with a **final fully-connected layer**.

# %%
def model_builder():
    
    model = Sequential([
        Embedding(embedding_matrix.shape[0],
                            embedding_matrix.shape[1],
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LEN,  
                            trainable=False),
        GlobalAveragePooling1D(),
        Dense(16,activation='relu' ),
        Dense(1, activation='sigmoid')], name="simple_model")

    return model

# %%
model= model_builder()
model.summary()
# Out:
# Model: "simple_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 250, 100)          9221100
#
#  global_average_pooling1d (  (None, 100)               0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                1616
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 9222733 (35.18 MB)
# Trainable params: 1633 (6.38 KB)
# Non-trainable params: 9221100 (35.18 MB)
# _________________________________________________________________

# %% [markdown]
# **Compile the Model**

# %%
model.compile(optimizer=Adam(learning_rate=LR), 
              loss=BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# **Train the Model**

# %%
# %%time
history= model.fit(X_train, y_train, 
                   batch_size= BATCH_SIZE,
                   epochs= EPOCHS, 
                   validation_split= 0.1,
                   verbose=1)
# Out:
# Epoch 1/10
# 1125/1125 [==============================] - 1s 995us/step - loss: 0.5139 - accuracy: 0.7591 - val_loss: 0.4967 - val_accuracy: 0.7722
# Epoch 2/10
# 1125/1125 [==============================] - 1s 908us/step - loss: 0.4643 - accuracy: 0.7877 - val_loss: 0.4488 - val_accuracy: 0.7975
# Epoch 3/10
# 1125/1125 [==============================] - 1s 915us/step - loss: 0.4490 - accuracy: 0.7916 - val_loss: 0.4608 - val_accuracy: 0.7860
# Epoch 4/10
# 1125/1125 [==============================] - 1s 925us/step - loss: 0.4442 - accuracy: 0.7944 - val_loss: 0.4560 - val_accuracy: 0.7855
# Epoch 5/10
# 1125/1125 [==============================] - 1s 914us/step - loss: 0.4390 - accuracy: 0.7964 - val_loss: 0.4370 - val_accuracy: 0.7945
# Epoch 6/10
# 1125/1125 [==============================] - 1s 929us/step - loss: 0.4363 - accuracy: 0.7973 - val_loss: 0.4344 - val_accuracy: 0.7997
# Epoch 7/10
# 1125/1125 [==============================] - 1s 909us/step - loss: 0.4336 - accuracy: 0.7989 - val_loss: 0.4390 - val_accuracy: 0.8005
# Epoch 8/10
# 1125/1125 [==============================] - 1s 917us/step - loss: 0.4303 - accuracy: 0.8010 - val_loss: 0.4337 - val_accuracy: 0.7947
# Epoch 9/10
# 1125/1125 [==============================] - 1s 911us/step - loss: 0.4271 - accuracy: 0.8038 - val_loss: 0.4244 - val_accuracy: 0.8015
# Epoch 10/10
# 1125/1125 [==============================] - 1s 933us/step - loss: 0.4266 - accuracy: 0.8031 - val_loss: 0.4273 - val_accuracy: 0.8027
# CPU times: user 16.6 s, sys: 8.62 s, total: 25.2 s
# Wall time: 10.6 s

# %% [markdown]
# **Model Evaluation**

# %%
# %%time
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# 313/313 [==============================] - 0s 770us/step - loss: 0.4348 - accuracy: 0.8005
# Test loss: 0.4348
# Test accuracy: 80.05%
# CPU times: user 464 ms, sys: 197 ms, total: 660 ms
# Wall time: 315 ms

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt .ylim(0,1)
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt .ylim(0,1)
plt.legend()

plt.show()

# %% [markdown]
# - The basic model achieved an accuracy of **80.05%** on the test data, yielding a loss of 0.4348.
#
# - The model exhibits **minimal overfitting** as the accuracy and loss values between training and cross-validation closely align. This suggests that the model generalizes well to unseen data, resulting in a balanced performance across both training and validation sets.

# %% [markdown]
# ### Build the Complex Model
#
# **Convolutional Neural Networks (CNN)** is used for our advanced model. This model employs an embedding layer to convert textual tokens into fixed-length vectors, creating a sequence of vectors from the input text. These vectors then undergo several layers of convolution and **max pooling** operations before reaching a final **fully-connected layer**. To prevent overfitting, **L2 regularization** is applied. The model's performance is further enhanced through the implementation of a **callbacks** mechanism.

# %%
def opt_model_builder():
    
    model = Sequential([
        Embedding(embedding_matrix.shape[0],
                            embedding_matrix.shape[1],
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LEN,  
                            trainable=False),
        Conv1D(128, 5, activation='relu', padding= "same", kernel_regularizer=regularizers.l2(l=0.0001)),
        MaxPooling1D(5, padding="same"),
        Flatten(),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l=0.0001)),
        Dense(1, activation='sigmoid')], name= "complex_model")

    return model

# %%
model= opt_model_builder()
model.summary()
# Out:
# Model: "complex_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 250, 100)          9221100
#
#  conv1d_1 (Conv1D)           (None, 250, 128)          64128
#
#  max_pooling1d_1 (MaxPoolin  (None, 50, 128)           0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 128)               819328
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10104685 (38.55 MB)
# Trainable params: 883585 (3.37 MB)
# Non-trainable params: 9221100 (35.18 MB)
# _________________________________________________________________

# %% [markdown]
# **Compile the Model**

# %%
model.compile(optimizer=Adam(learning_rate=LR), 
              loss=BinaryCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# **Callbacks**

# %%
callbacks =[ReduceLROnPlateau(monitor='val_loss', patience=3, cooldown=0),
            EarlyStopping(monitor='val_accuracy', min_delta=1e-4, patience=3)]

# %% [markdown]
# **Train the Model**

# %%
# %%time
history= model.fit(X_train, y_train, 
                   batch_size= BATCH_SIZE,
                   epochs= EPOCHS, 
                   validation_split= 0.1,
                   verbose=1,
                   callbacks= callbacks)
# Out:
# Epoch 1/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.5389 - accuracy: 0.7558 - val_loss: 0.4245 - val_accuracy: 0.8330 - lr: 0.0050
# Epoch 2/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.4225 - accuracy: 0.8392 - val_loss: 0.4260 - val_accuracy: 0.8340 - lr: 0.0050
# Epoch 3/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.4112 - accuracy: 0.8475 - val_loss: 0.4157 - val_accuracy: 0.8375 - lr: 0.0050
# Epoch 4/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.3996 - accuracy: 0.8516 - val_loss: 0.4126 - val_accuracy: 0.8372 - lr: 0.0050
# Epoch 5/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.3831 - accuracy: 0.8569 - val_loss: 0.4082 - val_accuracy: 0.8428 - lr: 0.0050
# Epoch 6/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.3746 - accuracy: 0.8619 - val_loss: 0.4105 - val_accuracy: 0.8350 - lr: 0.0050
# Epoch 7/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.3714 - accuracy: 0.8636 - val_loss: 0.4237 - val_accuracy: 0.8332 - lr: 0.0050
# Epoch 8/10
# 1125/1125 [==============================] - 16s 14ms/step - loss: 0.3676 - accuracy: 0.8670 - val_loss: 0.4141 - val_accuracy: 0.8403 - lr: 0.0050
# CPU times: user 8min 32s, sys: 1min 11s, total: 9min 44s
# Wall time: 2min 8s

# %% [markdown]
# **Model Evaluation**

# %%
# %%time
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4157 - accuracy: 0.8396
# Test loss: 0.4157
# Test accuracy: 83.96%
# CPU times: user 6.74 s, sys: 567 ms, total: 7.3 s
# Wall time: 1.43 s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt .ylim(0,1)
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt .ylim(0,1)
plt.legend()

plt.show()

# %% [markdown]
# - The complex model attained an accuracy of **83.96%** on the test data with a corresponding loss of 0.4157.
#
# - **Early stopping was applied**, concluding training after only 8 epochs due to a divergence between the training and validation loss, signaling effective early stopping.

# %% [markdown]
# **Model Comparison**

# %% [markdown]
# | Model   | Input Layer                         | Hidden Layer                                       | Output Layer       | Callbacks                                 | Accuracy |
# |---------|-------------------------------------|----------------------------------------------------|--------------------|-------------------------------------------|---------------|
# | Simple  | Embedding                            | Global Average Pooling + Fully-Connected           | Dense (Sigmoid)    | None                                      | 80.05%        |
# | Complex | Embedding                            | Convolutional + Max Pooling + Fully-Connected (L2 Regularization)      | Dense (Sigmoid)    | ReduceLROnPlateau + EarlyStopping          | 83.96%        |

# %% [markdown]
# ### Model Prediction

# %%
def decode_sentiment(score):
    return "positive" if score >= 0.5 else "negative"

# %%
def predict(text):
    # Tokenize text
    X_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=MAX_SEQUENCE_LEN)
    
    # Predict
    score = model.predict([X_test])[0]
    # Decode sentiment
    label = decode_sentiment(score)

    return {"label": label, "score": float(score)}

# %%
predict("The best movie I have ever watched")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# {'label': 'positive', 'score': 0.8585911393165588}

# %%
predict("I hate the movie")
# Out:
# 1/1 [==============================] - 0s 9ms/step
# {'label': 'negative', 'score': 0.3099493384361267}

# %% [markdown]
# **Confusion Matrix**

# %%
# %%time
scores = model.predict(X_test, verbose=1, batch_size=10000)
y_pred_1d = [decode_sentiment(score) for score in scores]
# Out:
# 1/1 [==============================] - 1s 1s/step
# CPU times: user 6.28 s, sys: 466 ms, total: 6.74 s
# Wall time: 1.09 s

# %%
cm= confusion_matrix(test_data['target'],y_pred_1d)
cm = (cm.astype('float') / cm.sum(axis=1))*100
df_cm= pd.DataFrame(cm, index=['True Positive', 'True Negative'], columns=['Predict Positive', 'Predict Negative'])
df_cm
# Out:
#                Predict Positive  Predict Negative
# True Positive         83.723236         16.565779
# True Negative         15.523394         84.200969

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(list(test_data['target']), y_pred_1d))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.84      0.84      5044
#     positive       0.84      0.84      0.84      4956
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %% [markdown]
# - The classification report indicates balanced performance for both positive and negative sentiments, with **precision, recall, and F1-score values around 0.84**. The **overall accuracy of 84%** suggests a well-performing model on the test data, achieving consistent results for both sentiment classes.

# %% [markdown]
# ### Save the Model

# %%
model.save(MODEL_PATH)
pickle.dump(tokenizer, open(TOKENIZER_MODEL, "wb"), protocol=pickle.HIGHEST_PROTOCOL)
pickle.dump(encoder, open(ENCODER_MODEL, "wb"), protocol=pickle.HIGHEST_PROTOCOL)
